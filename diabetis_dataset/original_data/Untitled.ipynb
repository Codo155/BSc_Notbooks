# %% [markdown]
# Adult dataset
# =======================================================

# %% [markdown]
# Imports & Warnings:

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# turn of warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading train and test datasets:

# %%
original = pandas.read_csv('covid_original.csv',encoding = "ISO-8859-1");
pandas.options.display.max_columns = None
display(original)
# Out:
#           ID  age     sex                        city       province country  \
# 0          1   30    male     Chaohu City, Hefei City          Anhui   China
# 1          2   47    male  Baohe District, Hefei City          Anhui   China
# 2          3   49    male  High-Tech Zone, Hefei City          Anhui   China
# 3          4   47  female  High-Tech Zone, Hefei City          Anhui   China
# 4          5   50  female  Feidong County, Hefei City          Anhui   China
# ...      ...  ...     ...                         ...            ...     ...
# 14597  14933  NaN     NaN                        Agra  Uttar Pradesh   India
# 14598  14934  NaN     NaN                        Agra  Uttar Pradesh   India
# 14599  14935  NaN     NaN                        Agra  Uttar Pradesh   India
# 14600  14936  NaN     NaN                         NaN      Telangana   India
# 14601  14937  NaN     NaN                         NaN      Telangana   India
#
# ...

# %%
original=original.drop(['latitude','longitude','date_onset_symptoms','date_admission_hospital','date_confirmation','lives_in_Wuhan','travel_history_dates','travel_history_location'],axis=1)
original=original.dropna(subset=['age'])

display(original.shape)
# Out:
# (1438, 25)

# %%
display(original.isnull().sum())
# Out:
# ID                             0
# age                            0
# sex                          167
# city                         202
# province                     169
# country                       21
# wuhan(0)_not_wuhan(1)          0
# geo_resolution                 2
# symptoms                     948
# reported_market_exposure    1400
# additional_information       552
# chronic_disease_binary      1415
# chronic_disease             1426
# source                        14
# sequence_available          1436
# outcome                     1269
# date_death_or_discharge     1357
# notes_for_discussion        1411
# location                    1075
# admin3                      1194
# admin2                       617
# admin1                       174
# country_new                   70
# admin_id                      49
# data_moderator_initials     1437
# dtype: int64

# %%
print(original.dtypes)
# Out:
# ID                            int64
# age                          object
# sex                          object
# city                         object
# province                     object
# country                      object
# wuhan(0)_not_wuhan(1)         int64
# geo_resolution               object
# symptoms                     object
# reported_market_exposure     object
# additional_information       object
# chronic_disease_binary      float64
# chronic_disease              object
# source                       object
# sequence_available           object
# outcome                      object
# date_death_or_discharge      object
# notes_for_discussion         object
# location                     object
# admin3                       object
# admin2                       object
# admin1                       object
# country_new                  object
# admin_id                     object
# data_moderator_initials      object
# dtype: object

# %%
original['outcome']= original['outcome'].astype('category')
for c in original['outcome'].cat.categories:
    print(c)
# Out:
# 05.02.2020
# Discharged
# Symptoms only improved with cough. Currently hospitalized for follow-up.
# death
# died
# discharge
# discharged
# not hospitalized
# recovered
# recovering at home 03.03.2020
# severe
# stable
# treated in an intensive care unit (14.02.2020)
# unknown

# %%
attribute='country'

# %%
original[attribute]= original[attribute].astype('category')
for c in original[attribute].cat.categories:
    print(c)
# Out:
# Afghanistan
# Algeria
# Andorra
# Argentina
# Australia
# Belgium
# Brazil
# Cambodia
# Canada
# Chile
# China
# Croatia
# Czech Republic
# Estonia
# Finland
# France
# Georgia
# Germany
# Greece
# Iceland
# Italy
# Japan
# Kuwait
# Lebanon
# Lithuania
# Malaysia
# Mexico
# Nepal
# Netherlands
# New Zealand
# North Macedonia
# Pakistan
# Philippines
# Portugal
# Qatar
# Romania
# Russia
# San Marino
# Senegal
# Singapore
# South Korea
# Spain
# Sri Lanka
# Sweden
# Switzerland
# Thailand
# Tunisia
# United Arab Emirates
# United States
# Vietnam
