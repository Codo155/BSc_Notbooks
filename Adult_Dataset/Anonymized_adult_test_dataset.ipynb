# %% [markdown]
# Anonymized Adult Test Dataset
# =======================================================

# %% [markdown]
# Imports & Warnings:

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# turn of warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading test datasets:

# %%
adult_test_data = pandas.read_csv('Anonymized/anonymized_adult_test_data02.csv', index_col= False);
display(adult_test_data.head())
# Out:
#         Age                            Workclass    fnlwgt  \
# 0  [40, 60[  {Federal-gov, Local-gov, State-gov}   96652.0
# 1  [40, 60[  {Federal-gov, Local-gov, State-gov}  265386.0
# 2  [40, 60[  {Federal-gov, Local-gov, State-gov}   47270.0
# 3  [20, 40[  {Federal-gov, Local-gov, State-gov}   90872.0
# 4  [20, 40[  {Federal-gov, Local-gov, State-gov}  243177.0
#
#                      Education Education-number  \
# 0      {Assoc-acdm, Assoc-voc}         [10, 15[
# 1      {Assoc-acdm, Assoc-voc}         [10, 15[
# 2      {Assoc-acdm, Assoc-voc}         [10, 15[
# 3  {Prof-school, Some-college}         [10, 15[
# 4  {Prof-school, Some-college}         [10, 15[
#
#                                       Marital-status    Occupation  \
# 0  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 1  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 2  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 3                 {Divorced, Widowed, Never-married}  Adm-clerical
# 4                 {Divorced, Widowed, Never-married}  Adm-clerical
#
#     Relationship Ethnicity     Sex  Capital-gain  Capital-loss  \
# 0      Unmarried     Black  Female           0.0           0.0
# 1      Unmarried     Black  Female           0.0           0.0
# 2      Unmarried     Black  Female           0.0           0.0
# 3  Not-in-family     Black  Female           0.0           0.0
# 4  Not-in-family     Black  Female           0.0           0.0
#
#    Hours-per-week Native-country     50k
# 0            40.0  United-States  <=50K.
# 1            40.0  United-States  <=50K.
# 2            40.0  United-States  <=50K.
# 3            40.0  United-States  <=50K.
# 4            40.0  United-States  <=50K.

# %% [markdown]
# ## Data Types
#
# The anonymization changed some continuous attributes to categorical. Types need to be checked and transformed again.

# %%
CATEGORICAL_ATTRIBUTES= np.array(['Age', 'Workclass', 'Education','Education-number', 'Marital-status', 'Occupation','Relationship','Ethnicity','Sex','Native-country','50k']) 
CONTINUOUS_ATTRIBUTES= np.array(['fnlwgt', 'Capital-gain', 'Capital-loss', 'Hours-per-week']) 
for col in CATEGORICAL_ATTRIBUTES:
   adult_test_data[col]=adult_test_data[col].astype('category')

# %%
display(adult_test_data.dtypes)
# Out:
# Age                 category
# Workclass           category
# fnlwgt               float64
# Education           category
# Education-number    category
# Marital-status      category
# Occupation          category
# Relationship        category
# Ethnicity           category
# Sex                 category
# Capital-gain         float64
# Capital-loss         float64
# Hours-per-week       float64
# Native-country      category
# 50k                 category
# dtype: object

# %%
display(adult_test_data.head())
# Out:
#         Age                            Workclass    fnlwgt  \
# 0  [40, 60[  {Federal-gov, Local-gov, State-gov}   96652.0
# 1  [40, 60[  {Federal-gov, Local-gov, State-gov}  265386.0
# 2  [40, 60[  {Federal-gov, Local-gov, State-gov}   47270.0
# 3  [20, 40[  {Federal-gov, Local-gov, State-gov}   90872.0
# 4  [20, 40[  {Federal-gov, Local-gov, State-gov}  243177.0
#
#                      Education Education-number  \
# 0      {Assoc-acdm, Assoc-voc}         [10, 15[
# 1      {Assoc-acdm, Assoc-voc}         [10, 15[
# 2      {Assoc-acdm, Assoc-voc}         [10, 15[
# 3  {Prof-school, Some-college}         [10, 15[
# 4  {Prof-school, Some-college}         [10, 15[
#
#                                       Marital-status    Occupation  \
# 0  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 1  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 2  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 3                 {Divorced, Widowed, Never-married}  Adm-clerical
# 4                 {Divorced, Widowed, Never-married}  Adm-clerical
#
#     Relationship Ethnicity     Sex  Capital-gain  Capital-loss  \
# 0      Unmarried     Black  Female           0.0           0.0
# 1      Unmarried     Black  Female           0.0           0.0
# 2      Unmarried     Black  Female           0.0           0.0
# 3  Not-in-family     Black  Female           0.0           0.0
# 4  Not-in-family     Black  Female           0.0           0.0
#
#    Hours-per-week Native-country     50k
# 0            40.0  United-States  <=50K.
# 1            40.0  United-States  <=50K.
# 2            40.0  United-States  <=50K.
# 3            40.0  United-States  <=50K.
# 4            40.0  United-States  <=50K.

# %% [markdown]
# ### Quantity anonymized test dataset

# %%
for attribute,value in adult_test_data.iteritems():
   adult_test_data[attribute]= adult_test_data[attribute].replace('*',np.NAN)

# %%
display(adult_test_data.head())
# Out:
#         Age                            Workclass    fnlwgt  \
# 0  [40, 60[  {Federal-gov, Local-gov, State-gov}   96652.0
# 1  [40, 60[  {Federal-gov, Local-gov, State-gov}  265386.0
# 2  [40, 60[  {Federal-gov, Local-gov, State-gov}   47270.0
# 3  [20, 40[  {Federal-gov, Local-gov, State-gov}   90872.0
# 4  [20, 40[  {Federal-gov, Local-gov, State-gov}  243177.0
#
#                      Education Education-number  \
# 0      {Assoc-acdm, Assoc-voc}         [10, 15[
# 1      {Assoc-acdm, Assoc-voc}         [10, 15[
# 2      {Assoc-acdm, Assoc-voc}         [10, 15[
# 3  {Prof-school, Some-college}         [10, 15[
# 4  {Prof-school, Some-college}         [10, 15[
#
#                                       Marital-status    Occupation  \
# 0  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 1  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 2  {Married-AF-spouse, Married-civ-spouse, Marrie...  Adm-clerical
# 3                 {Divorced, Widowed, Never-married}  Adm-clerical
# 4                 {Divorced, Widowed, Never-married}  Adm-clerical
#
#     Relationship Ethnicity     Sex  Capital-gain  Capital-loss  \
# 0      Unmarried     Black  Female           0.0           0.0
# 1      Unmarried     Black  Female           0.0           0.0
# 2      Unmarried     Black  Female           0.0           0.0
# 3  Not-in-family     Black  Female           0.0           0.0
# 4  Not-in-family     Black  Female           0.0           0.0
#
#    Hours-per-week Native-country     50k
# 0            40.0  United-States  <=50K.
# 1            40.0  United-States  <=50K.
# 2            40.0  United-States  <=50K.
# 3            40.0  United-States  <=50K.
# 4            40.0  United-States  <=50K.

# %%
display(adult_test_data.isnull().sum())
seriesObj = adult_test_data.apply(lambda x: x.isnull().any(), axis=1)
nanRows = len(seriesObj[seriesObj == True].index)
rows = adult_test_data.shape[0]
print('Rows in total: ', rows)
print('Number of Rows in dataframe which contain NaN in any column : ', nanRows)
print('% nan :', (nanRows/rows)*100)
# Out:
# Age                 2983
# Workclass           2983
# fnlwgt                 0
# Education           2983
# Education-number    2983
# Marital-status      2983
# Occupation          2983
# Relationship        2983
# Ethnicity           2983
# Sex                 2983
# Capital-gain           0
# Capital-loss           0
# Hours-per-week         0
# Native-country         0
# 50k                    0
# dtype: int64
# Rows in total:  15060
# Number of Rows in dataframe which contain NaN in any column :  2983
# % nan : 19.807436918990703

# %% [markdown]
# During the anonymization process a supression limt of 20% were configured to eliminate outliers.
# 19.5% were elimanted and the rows were marked with '\*'. After replacing the character witn numpy.NAN the affected rows will be deleted.

# %%
adult_test_data=adult_test_data.dropna()
rows = adult_test_data.shape[0]
print('Rows in total: ', rows)
# Out:
# Rows in total:  12077

# %% [markdown]
# ## Anonymized Test Dataset Description

# %%
print(adult_test_data.describe());
fig = adult_test_data.hist(column=CONTINUOUS_ATTRIBUTES, figsize=(12,8))
# Out:
#              fnlwgt  Capital-gain  Capital-loss  Hours-per-week
# count  1.207700e+04  12077.000000  12077.000000    12077.000000
# mean   1.890198e+05   1165.566200     91.659518       41.392068
# std    1.039059e+05   7819.551035    410.680965       11.883372
# min    1.930200e+04      0.000000      0.000000        1.000000
# 25%    1.172100e+05      0.000000      0.000000       40.000000
# 50%    1.783630e+05      0.000000      0.000000       40.000000
# 75%    2.373860e+05      0.000000      0.000000       45.000000
# max    1.490400e+06  99999.000000   3770.000000       99.000000

# %%
for cat in CATEGORICAL_ATTRIBUTES:
    fig, ax = plt.subplots()
    adult_test_data[cat].value_counts().plot(ax=ax, kind='bar')

# %% [markdown]
# ## Save to CSV
#
# (un)comment it

# %%
#adult_test_data.to_csv("Anonymized_finished/test03.csv", encoding='utf-8',header=True)
